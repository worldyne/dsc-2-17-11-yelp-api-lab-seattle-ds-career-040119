# %% [markdown]
# # Yelp API - Lab
#
# The previously deployed lab on working around building a GIS with Yelp API and Folium can be found [here](https://github.com/learn-co-curriculum/dsc-2-15-10-yelp-api-gis-lab/tree/a56358c2d0c2daf569a5f50937c4c27463aadb1a) (not relevant for new students).
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, and some basic Folium visualizations its time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.

# %% [markdown]
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
#Your code here
import requests
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)
    
keys = get_keys('/Users/lawrencechew/.secret/yelp_api.json')
client_id = keys['client_id']
api_key = keys['api_key']
SEARCH_LIMIT = 50
term = 'Boba'
location = 'Seattle, WA'
url = 'https://api.yelp.com/v3/businesses/search'
headers = {
    'Authorization': f'Bearer {api_key}',
}

url_params = {
    'term': term.replace(' ', '+'),
    'location': location.replace(' ', '+'),
    'limit': SEARCH_LIMIT
}
resp = requests.get(url, headers=headers, params=url_params)
print(resp)
print(resp.status_code)
# Out:
# <Response [200]>
# 200

# %%
resp.json()
# Out:
# {'businesses': [{'id': 'xI0ayTQVBIAkZpJiWk-SNQ',
#    'alias': '20-oz-tea-seattle',
#    'name': '20 OZ TEA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QfzSrqdHp1UNOADfd2y65A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/20-oz-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 199,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.63568, 'longitude': -122.32591},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1823 Eastlake Ave E',
#     'address2': 'Ste 160',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1823 Eastlake Ave E',
#      'Ste 160',
#      'Seattle, WA 98102']},
#    'phone': '+12067126027',
#    'display_phone': '(206) 712-6027',
#    'distance': 1343.3247175837273},
#   {'id': 'BFTaYXgJDxQY38MQZAWZFQ',
#    'alias': 'young-tea-seattle',
#    'name': 'Young Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gM3X_kvwJBtd8T7xV2FiFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/young-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 398,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.59733, 'longitude': -122.32597},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '609 S Weller St',
#     'address2': 'Unit B',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['609 S Weller St', 'Unit B', 'Seattle, WA 98104']},
#    'phone': '+12066826688',
#    'display_phone': '(206) 682-6688',
#    'distance': 3202.1016999196218},
#   {'id': 'BXjaJd5j3BJl8K4EVdSvEA',
#    'alias': 'atulea-seattle',
#    'name': 'Atulea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fyG1DEJfRImXGBstRqym9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atulea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 69,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.61691, 'longitude': -122.31718},
#    'transactions': [],
#    'location': {'address1': '1715 12th Ave',
#     'address2': 'Suite.100',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1715 12th Ave', 'Suite.100', 'Seattle, WA 98122']},
#    'phone': '+12064135903',
#    'display_phone': '(206) 413-5903',
#    'distance': 1666.6735649725197},
#   {'id': 'nDvwrhWdB7kjIwn2Z83lSQ',
#    'alias': 'seattle-best-tea-seattle',
#    'name': 'Seattle Best Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sw2oBmh64zKRPrwlM6O1ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seattle-best-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 279,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.59846, 'longitude': -122.32731},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '506 S King St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['506 S King St', 'Seattle, WA 98104']},
#    'phone': '+12067499855',
#    'display_phone': '(206) 749-9855',
#    'distance': 3052.028625218399},
#   {'id': 'DD2UG9WnSJMvg2QHsQJeZQ',
#    'alias': 'boba-up-seattle-3',
#    'name': 'Boba Up',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9QeEr5n863RIvFynlhjpFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boba-up-seattle-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 113,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.65807, 'longitude': -122.31354},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4141 University Way NE',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4141 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12065478800',
#    'display_phone': '(206) 547-8800',
#    'distance': 3991.4048233596122},
#   {'id': '1ZnlSbwJpc9qwHyK8C0BfA',
#    'alias': 'dreamy-drinks-seattle-4',
#    'name': 'Dreamy Drinks',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H6WWz4Tm6leejUpt5FJQSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dreamy-drinks-seattle-4?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 42,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61125, 'longitude': -122.33493},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['Seattle, WA 98101']},
#    'phone': '+14253820796',
#    'display_phone': '(425) 382-0796',
#    'distance': 1883.3883969473607},
#   {'id': 'RJc4imo4ypsU5k3VeIV2qw',
#    'alias': 'sharetea-seattle-3',
#    'name': 'Sharetea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u-nmdDYS2aOdoNykOO2bpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sharetea-seattle-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 460,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6613402793565,
#     'longitude': -122.316258698702},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1100 NE 45th St',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1100 NE 45th St', 'Ste 100', 'Seattle, WA 98105']},
#    'phone': '+12066321038',
#    'display_phone': '(206) 632-1038',
#    'distance': 4246.668262597241},
#   {'id': 'wEsKFcjc1WlY_TFnQkKfvA',
#    'alias': 'the-moo-bar-seattle-3',
#    'name': 'The Moo Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jIUsstr58kvarskY_KUtyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-moo-bar-seattle-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 264,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 47.61736, 'longitude': -122.33804},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2124 Westlake Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2124 Westlake Ave', 'Seattle, WA 98121']},
#    'phone': '+12064673191',
#    'display_phone': '(206) 467-3191',
#    'distance': 906.8386909768128},
#   {'id': '5t7AE21vUB3CnxxkaaFsaQ',
#    'alias': 'oasis-tea-zone-seattle-4',
#    'name': 'Oasis Tea Zone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HgGImC37W0AtrUzS9LQ__Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oasis-tea-zone-seattle-4?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 144,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.6154, 'longitude': -122.32388},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '606 E Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['606 E Pine St', 'Seattle, WA 98122']},
#    'phone': '+12063974333',
#    'display_phone': '(206) 397-4333',
#    'distance': 1385.1776512367103},
#   {'id': 'Yb08Q7BFawBi2g2W2d4Xqg',
#    'alias': 'sharetea-seattle-4',
#    'name': 'Sharetea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qVof3QiE4r4R80duTlgZzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sharetea-seattle-4?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 47,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.607, 'longitude': -122.32039},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '530 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['530 Broadway', 'Seattle, WA 98122']},
#    'phone': '+14258298644',
#    'display_phone': '(425) 829-8644',
#    'distance': 2333.197096345198},
#   {'id': 'MWj_fdMMixz5gbdZZWDYPw',
#    'alias': 'yifang-taiwan-fruit-tea-lynnwood',
#    'name': 'Yifang Taiwan Fruit Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2bDOmuV_xEik5FC5tCrZYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yifang-taiwan-fruit-tea-lynnwood?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 29,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.830005, 'longitude': -122.274381},
#    'transactions': [],
#    'location': {'address1': '3000 184th St SW',
#     'address2': 'Ste 190',
#     'address3': '',
#     'city': 'Lynnwood',
#     'zip_code': '98037',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['3000 184th St SW', 'Ste 190', 'Lynnwood, WA 98037']},
#    'phone': '+14254124864',
#    'display_phone': '(425) 412-4864',
#    'distance': 23203.818079983237},
#   {'id': 'LQUecX5mXFJqKZWc4hjiKA',
#    'alias': 'happy-lemon-bellevue-2',
#    'name': 'Happy Lemon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3xtPivZGKSxqzPN9a_U3Jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-lemon-bellevue-2?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 14,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.62576, 'longitude': -122.15473},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1645 140th Ave NE',
#     'address2': 'Ste B8',
#     'address3': '',
#     'city': 'Bellevue',
#     'zip_code': '98005',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1645 140th Ave NE', 'Ste B8', 'Bellevue, WA 98005']},
#    'phone': '+14256432460',
#    'display_phone': '(425) 643-2460',
#    'distance': 13550.404791073588},
#   {'id': 'iC6X9Z_ZhUfCaycZurGlUA',
#    'alias': 'iki-tea-seattle',
#    'name': 'iki tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_keib83AFQVGplog4T_qGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iki-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 13,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61424, 'longitude': -122.3198},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '916 E Pike St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['916 E Pike St', 'Seattle, WA 98122']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1709.8702401578435},
#   {'id': 'Jtmxge2f2qVi_wvi5ODGxQ',
#    'alias': 'ding-tea-seattle-seattle',
#    'name': 'Ding Tea Seattle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qg89KlkJR6ATnYO0A-gsCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ding-tea-seattle-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 85,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.66386, 'longitude': -122.31339},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4725 University Way NE',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4725 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12064567192',
#    'display_phone': '(206) 456-7192',
#    'distance': 4581.598204108754},
#   {'id': 'F18suFsmc9j5srBk36GXaA',
#    'alias': 'tea-republik-seattle',
#    'name': 'Tea Republik',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qj5AMto7SpIkVuUnpSl7cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-republik-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 296,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6620911, 'longitude': -122.3132793},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4527 University Way NE',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4527 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12064977631',
#    'display_phone': '(206) 497-7631',
#    'distance': 4404.739300908155},
#   {'id': '_g_uT28EKysvhrZGgS-qbg',
#    'alias': 'happy-lemon-bellevue',
#    'name': 'Happy Lemon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PaObbHfbJT8OiIcpyNifzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-lemon-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 257,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.615121, 'longitude': -122.203117},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1031 Bellevue Sq',
#     'address2': '',
#     'address3': None,
#     'city': 'Bellevue',
#     'zip_code': '98004',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1031 Bellevue Sq', 'Bellevue, WA 98004']},
#    'phone': '+14254535352',
#    'display_phone': '(425) 453-5352',
#    'distance': 9988.708186313157},
#   {'id': 'Nfup0tT2C1Fptjibu15HSg',
#    'alias': 'bobachine-seattle',
#    'name': 'Bobachine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-Tckw7mbVWP1cIli4Is_Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bobachine-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 271,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 47.61083, 'longitude': -122.33669},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1514 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1514 4th Ave', 'Seattle, WA 98101']},
#    'phone': '+12064472622',
#    'display_phone': '(206) 447-2622',
#    'distance': 1624.087231910145},
#   {'id': 'lhP8uwAgPZ5Fs6wkXuUdNw',
#    'alias': 'yoyo-station-seattle-5',
#    'name': 'Yoyo Station',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gjlrGhEM8zHROfXyvIxwrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoyo-station-seattle-5?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 53,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.6200594, 'longitude': -122.32064},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '202 Broadway E',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['202 Broadway E', 'Seattle, WA 98102']},
#    'phone': '+12063291756',
#    'display_phone': '(206) 329-1756',
#    'distance': 1263.8115546563192},
#   {'id': 'gXRtRRpbeSdkoJFW-gwk1A',
#    'alias': 'bambu-seattle-2',
#    'name': 'BAMBU',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_CQuXC7vMMx9BwiKKl6BTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bambu-seattle-2?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 393,
#    'categories': [{'alias': 'shavedice', 'title': 'Shaved Ice'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59785, 'longitude': -122.32338},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '516 7th Ave S',
#     'address2': 'Unit A',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['516 7th Ave S', 'Unit A', 'Seattle, WA 98104']},
#    'phone': '+12065380399',
#    'display_phone': '(206) 538-0399',
#    'distance': 3190.653683248933},
#   {'id': 'muiocC26CyttXAalS23cuQ',
#    'alias': 'wow-bubble-tea-seattle',
#    'name': 'WOW Bubble Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NNS-9hI7PGlmLxqFt0PpAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wow-bubble-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 292,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6628435, 'longitude': -122.3132573},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4553 University Way NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4553 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12066331229',
#    'display_phone': '(206) 633-1229',
#    'distance': 4482.911140696804},
#   {'id': 'EPZeu6ALh4zvSs06cLvmcg',
#    'alias': 'vivi-bubble-tea-redmond-redmond',
#    'name': 'Vivi Bubble Tea - Redmond',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m5ufufclkzSIegUTo4mFHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vivi-bubble-tea-redmond-redmond?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 102,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.67602, 'longitude': -122.12724},
#    'transactions': [],
#    'location': {'address1': '8145 161st Ave NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Redmond',
#     'zip_code': '98052',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['8145 161st Ave NE', 'Redmond, WA 98052']},
#    'phone': '+14259688200',
#    'display_phone': '(425) 968-8200',
#    'distance': 16581.055119528388},
#   {'id': 'QSOJshpTpNWClcUmdvyAYw',
#    'alias': 'kung-fu-tea-seattle',
#    'name': 'Kung Fu Tea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jbKm9gop-T2WkOCfN4ThIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kung-fu-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 166,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6640289613428,
#     'longitude': -122.312810897055},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4730 University Way NE',
#     'address2': 'Ste 109-110',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4730 University Way NE',
#      'Ste 109-110',
#      'Seattle, WA 98105']},
#    'phone': '+12062943900',
#    'display_phone': '(206) 294-3900',
#    'distance': 4617.739008386407},
#   {'id': 'M4BjcVhOEjVgeF8EeSjZPQ',
#    'alias': 'oasis-tea-zone-seattle',
#    'name': 'Oasis Tea Zone',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gLMPkwlTZ4CqcM6gEGTGyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oasis-tea-zone-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 740,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.5976518611681,
#     'longitude': -122.326559026402},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '519 6th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['519 6th Ave S', 'Seattle, WA 98104']},
#    'phone': '+12064478098',
#    'display_phone': '(206) 447-8098',
#    'distance': 3159.638768819001},
#   {'id': 'OY8SMbc31wXMcHs5UzqsUw',
#    'alias': 'citra-seattle',
#    'name': 'Citra',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jo-fVrNNeUNWCR64Zx4B3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citra-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 193,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6638174140586,
#     'longitude': -122.312971447885},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4730 University Way NE',
#     'address2': 'Ste 105',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4730 University Way NE',
#      'Ste 105',
#      'Seattle, WA 98105']},
#    'phone': '+12063279012',
#    'display_phone': '(206) 327-9012',
#    'distance': 4591.441836080162},
#   {'id': 'ISHrur1Mkqhvp921Ei_QhQ',
#    'alias': 'bobalust-tea-house-tukwila',
#    'name': 'BobaLust Tea House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4beW8byf6cky5NjPxWFkVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bobalust-tea-house-tukwila?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 257,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.46093, 'longitude': -122.25343},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '319 Tukwila Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Tukwila',
#     'zip_code': '98188',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['319 Tukwila Pkwy', 'Tukwila, WA 98188']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 19299.555049156257},
#   {'id': 'O3BvKUxzp7N_08p5HQiW5A',
#    'alias': 'blank-space-cafe-seattle-seattle',
#    'name': 'Blank Space Cafe - Seattle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mlFWVxz5TshXkGStcgigIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-space-cafe-seattle-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 142,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 47.6131993274362,
#     'longitude': -122.344044940179},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2126 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2126 2nd Ave', 'Seattle, WA 98121']},
#    'phone': '+12064482617',
#    'display_phone': '(206) 448-2617',
#    'distance': 1501.8160936810452},
#   {'id': 'aj8o1v1XjcbKF5hRCon13w',
#    'alias': 'coffee-tree-and-poke-seattle',
#    'name': 'Coffee Tree & Poke',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0VWX_6me6iUVyZayUOqk0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-tree-and-poke-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 109,
#    'categories': [{'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6058616638184,
#     'longitude': -122.325469970703},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '613 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['613 9th Ave', 'Seattle, WA 98104']},
#    'phone': '+12069923947',
#    'display_phone': '(206) 992-3947',
#    'distance': 2296.0417510392567},
#   {'id': 'rFC0LUPyhgyP7UC9ehkrHw',
#    'alias': 'jazen-tea-seattle-3',
#    'name': 'Jazen Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d6yzDoslzi-1bERESJA3dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jazen-tea-seattle-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5977133, 'longitude': -122.325291},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '618 S Weller St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['618 S Weller St', 'Seattle, WA 98104']},
#    'phone': '+12066247189',
#    'display_phone': '(206) 624-7189',
#    'distance': 3174.5512730015257},
#   {'id': 'iI2Q70j_xgua1KUqXkHuWA',
#    'alias': 'qq-by-facing-east-seattle',
#    'name': 'Qq by Facing East',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ErU6OWB9TTjPkwxnhHdlZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qq-by-facing-east-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 100,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61701, 'longitude': -122.34326},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2325 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2325 6th Ave', 'Seattle, WA 98121']},
#    'phone': '+12064203408',
#    'display_phone': '(206) 420-3408',
#    'distance': 1093.3612259077202},
#   {'id': 'F5XwNjPQp_234lP986yeWg',
#    'alias': 'blackbird-seattle-bellevue-3',
#    'name': 'Blackbird Seattle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S8u547wFzSoXnRqhoXLpqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbird-seattle-bellevue-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 86,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.62036, 'longitude': -122.19322},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11004 NE 11th St',
#     'address2': 'Ste 108',
#     'address3': '',
#     'city': 'Bellevue',
#     'zip_code': '98004',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['11004 NE 11th St', 'Ste 108', 'Bellevue, WA 98004']},
#    'phone': '+14255982111',
#    'display_phone': '(425) 598-2111',
#    'distance': 10674.28434172254},
#   {'id': '4FKoEQz5Tu9qpQEAcET5gQ',
#    'alias': 'blank-space-cafe-green-lake-seattle',
#    'name': 'Blank Space Cafe - Green Lake',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q-Y88y9_-xYalupwm-dNHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-space-cafe-green-lake-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 47,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.68097, 'longitude': -122.32475},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7214 Woodlawn Ave NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98115',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['7214 Woodlawn Ave NE', 'Seattle, WA 98115']},
#    'phone': '+12064204348',
#    'display_phone': '(206) 420-4348',
#    'distance': 6229.942337470645},
#   {'id': 'BsnctWRn5l0-nCZfPsB_Ig',
#    'alias': 'coco-fresh-tea-and-juice-bellevue',
#    'name': 'CoCo Fresh Tea & Juice',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r2V_Rb4H2ykp9pl-AlEIzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coco-fresh-tea-and-juice-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 187,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6176699, 'longitude': -122.19283},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '11028 NE 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Bellevue',
#     'zip_code': '98004',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['11028 NE 8th St', 'Bellevue, WA 98004']},
#    'phone': '+14253626962',
#    'display_phone': '(425) 362-6962',
#    'distance': 10734.103460586795},
#   {'id': 'wG-dNNFINqU_Y--sT4kHvw',
#    'alias': 'kung-fu-tea-bellevue',
#    'name': 'Kung Fu Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gFfpcTtSj0A7kusi-I29qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kung-fu-tea-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 17,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6125662230073,
#     'longitude': -122.198798462876},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '288 106th Ave NE',
#     'address2': '',
#     'address3': None,
#     'city': 'Bellevue',
#     'zip_code': '98004',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['288 106th Ave NE', 'Bellevue, WA 98004']},
#    'phone': '+12064579529',
#    'display_phone': '(206) 457-9529',
#    'distance': 10345.965836738676},
#   {'id': '5oFtM6xwp4Z9aSHtFdEaHw',
#    'alias': 'braganza-tea-seattle',
#    'name': 'Braganza Tea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k3_7QsMV7JjHsn7GlbpXfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/braganza-tea-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 94,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.7049800922204,
#     'longitude': -122.325839634918},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '401 NE Northgate Way',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98125',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['401 NE Northgate Way', 'Seattle, WA 98125']},
#    'phone': '+12069627356',
#    'display_phone': '(206) 962-7356',
#    'distance': 8876.365884433168},
#   {'id': 'EoupzbxGRSEJpPhWx-NttQ',
#    'alias': 'bubble-tea-fresh-fruit-juice-seattle',
#    'name': 'Bubble Tea Fresh Fruit Juice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tJa1EXHxHQ5pJ8MvN5RuFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubble-tea-fresh-fruit-juice-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 62,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59893, 'longitude': -122.31779},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1043 S Jackson St',
#     'address2': 'Ste 102',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1043 S Jackson St', 'Ste 102', 'Seattle, WA 98104']},
#    'phone': '+12063295979',
#    'display_phone': '(206) 329-5979',
#    'distance': 3232.584416862985},
#   {'id': 'kV3_GeoCA8ZIJzZaaIuPfg',
#    'alias': 'c-fruit-life-seattle',
#    'name': 'C Fruit Life',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kw9lpHgEFP5jHYsxEESPaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c-fruit-life-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 115,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.65714, 'longitude': -122.31404},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4106 Brooklyn Ave NE',
#     'address2': 'Ste 103A',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4106 Brooklyn Ave NE',
#      'Ste 103A',
#      'Seattle, WA 98105']},
#    'phone': '+12064026171',
#    'display_phone': '(206) 402-6171',
#    'distance': 3875.7975086394304},
#   {'id': 'MkpxzydzUlGri6HXnKCI9w',
#    'alias': 'cold-plate-seattle',
#    'name': 'Cold Plate',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7xLc9WaZZSO6p-MWdJySjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cold-plate-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 57,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.66776, 'longitude': -122.3127},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5240 University Way NE',
#     'address2': 'Ste B',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['5240 University Way NE',
#      'Ste B',
#      'Seattle, WA 98105']},
#    'phone': '+12062945938',
#    'display_phone': '(206) 294-5938',
#    'distance': 5012.576377114735},
#   {'id': '17L8sQyrmtcB6rsR8SPQrA',
#    'alias': 'blackball-desserts-seattle',
#    'name': 'Blackball Desserts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ha4FnEEeCqXmnjsy7ysCvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackball-desserts-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 126,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 47.5982449743252,
#     'longitude': -122.324881422702},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '651 S King St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['651 S King St', 'Seattle, WA 98104']},
#    'phone': '+12065380596',
#    'display_phone': '(206) 538-0596',
#    'distance': 3124.897594788042},
#   {'id': 'CLMT6xTZ8jpot28Tl3XwOg',
#    'alias': 'sharetea-bellevue',
#    'name': 'Sharetea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NWya2ETrxdTb42IZHorNkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sharetea-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 118,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.62042, 'longitude': -122.19332},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1112 110th Ave Ne',
#     'address2': 'Ste 107',
#     'address3': None,
#     'city': 'Bellevue',
#     'zip_code': '98004',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1112 110th Ave Ne', 'Ste 107', 'Bellevue, WA 98004']},
#    'phone': '+14254433138',
#    'display_phone': '(425) 443-3138',
#    'distance': 10662.78924661439},
#   {'id': 'a5VwhTHeo1C4_KI45T8f-A',
#    'alias': 'mr-wish-bellevue',
#    'name': 'Mr. Wish',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3Baxpe0pHWwljz3QKeBUfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-wish-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 45,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.62712, 'longitude': -122.14639},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '14509 NE 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Bellevue',
#     'zip_code': '98007',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['14509 NE 20th St', 'Bellevue, WA 98007']},
#    'phone': '+14252082222',
#    'display_phone': '(425) 208-2222',
#    'distance': 14159.94941249761},
#   {'id': 'WypboGIF_sUhemucdV1wlQ',
#    'alias': 'over-the-rainbow-tea-bar-renton',
#    'name': 'Over The Rainbow Tea Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lEAR6bAkauRx8vBZEOoosg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/over-the-rainbow-tea-bar-renton?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 237,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.4894447, 'longitude': -122.1540903},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4820 4th St',
#     'address2': 'Ste A101',
#     'address3': '',
#     'city': 'Renton',
#     'zip_code': '98059',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4820 4th St', 'Ste A101', 'Renton, WA 98059']},
#    'phone': '+14255725764',
#    'display_phone': '(425) 572-5764',
#    'distance': 20345.438638498184},
#   {'id': 'aehEcMofRIwUiiLXPAOYXw',
#    'alias': 'ambrosia-cafe-seattle',
#    'name': 'Ambrosia Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4ByF1M_Q0vK-ZRTS-HnsiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ambrosia-cafe-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 346,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.5982, 'longitude': -122.32542},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '619 S King St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['619 S King St', 'Seattle, WA 98104']},
#    'phone': '+12066239028',
#    'display_phone': '(206) 623-9028',
#    'distance': 3115.6000606624484},
#   {'id': 'beCtdOgTiWo2A0nFvPEwmw',
#    'alias': 'the-bubble-tea-shop-seattle-3',
#    'name': 'The Bubble Tea Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NFT7xT127QXK8U8b0QQ4WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bubble-tea-shop-seattle-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 116,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 47.62198, 'longitude': -122.35166},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '305 Harrison St',
#     'address2': 'Ste C',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98109',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['305 Harrison St', 'Ste C', 'Seattle, WA 98109']},
#    'phone': '+12064482383',
#    'display_phone': '(206) 448-2383',
#    'distance': 1276.7110221762905},
#   {'id': 'uy-0d4POQHK1g9A3QYGDPw',
#    'alias': 'böba-bothell-2',
#    'name': 'Böba',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lb5SmirSJJZ3oSFa780IaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%B6ba-bothell-2?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 72,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.7905299, 'longitude': -122.21705},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '22833 Bothell-Everett Hwy',
#     'address2': 'Ste 155',
#     'address3': '',
#     'city': 'Bothell',
#     'zip_code': '98021',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['22833 Bothell-Everett Hwy',
#      'Ste 155',
#      'Bothell, WA 98021']},
#    'phone': '+14254839131',
#    'display_phone': '(425) 483-9131',
#    'distance': 20404.372509727997},
#   {'id': 'uf0F97LL1Pju0Cc6_qQe8A',
#    'alias': 'chatime-mlk-seattle',
#    'name': 'Chatime MLK',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/At-0vDPwXjO6CR_bhw7yiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatime-mlk-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 83,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.546908418106,
#     'longitude': -122.286118931612},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6014 Martin Luther King Jr Way S',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98118',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['6014 Martin Luther King Jr Way S',
#      'Seattle, WA 98118']},
#    'phone': '+12064662791',
#    'display_phone': '(206) 466-2791',
#    'distance': 9483.363359006918},
#   {'id': 'NX5anxnZ783VbNNNumMvgA',
#    'alias': 'kiki-cafe-and-teahouse-seattle-3',
#    'name': 'Kiki Cafe & Teahouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qnSaXOwvD-jFeZ2VB7gdQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kiki-cafe-and-teahouse-seattle-3?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 46,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6635, 'longitude': -122.31609},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '4708 11th Ave NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4708 11th Ave NE', 'Seattle, WA 98105']},
#    'phone': '+12068233688',
#    'display_phone': '(206) 823-3688',
#    'distance': 4461.92601388734},
#   {'id': 'Km-xjUYYY6GvpI2YIa2iVw',
#    'alias': 'drive-thru-boba-bellevue',
#    'name': 'Drive Thru Boba',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RQNqX-iv0evboh9UVu64SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drive-thru-boba-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 372,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.61361, 'longitude': -122.20104},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10435 NE 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bellevue',
#     'zip_code': '98004',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['10435 NE 4th St', 'Bellevue, WA 98004']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10171.408267809764},
#   {'id': '0kqpRFtiDOVre6aeHKyNoQ',
#    'alias': 'shake-it-kirkland-4',
#    'name': 'Shake It',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KI7BHcnDwkwk60z3kK8wug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shake-it-kirkland-4?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 120,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.71271, 'longitude': -122.18698},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '12561 116th Ave NE',
#     'address2': None,
#     'address3': None,
#     'city': 'Kirkland',
#     'zip_code': '98034',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['12561 116th Ave NE', 'Kirkland, WA 98034']},
#    'phone': '+14258180882',
#    'display_phone': '(425) 818-0882',
#    'distance': 14764.062743139923},
#   {'id': 'hM03ua-PXyjifojJQUAqNw',
#    'alias': 'pearls-tea-and-cafe-seattle',
#    'name': 'Pearls Tea & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pn-07AfSDDMKEb4UEEQFDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pearls-tea-and-cafe-seattle?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 187,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.55914, 'longitude': -122.36263},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4800 Delridge Way SW',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98106',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4800 Delridge Way SW', 'Seattle, WA 98106']},
#    'phone': '+12069376036',
#    'display_phone': '(206) 937-6036',
#    'distance': 7643.502097837889},
#   {'id': 'G9eADRZysfU5Po9IFhkZEQ',
#    'alias': 'meet-fresh-bellevue',
#    'name': 'Meet Fresh',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V-T-8SXm7nR9rD7i6OLUMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meet-fresh-bellevue?adjust_creative=QBMscBiEf3ywbPpfd5fAOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QBMscBiEf3ywbPpfd5fAOw',
#    'review_count': 130,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.60363, 'longitude': -122.13226},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15552 Lake Hills Blvd',
#     'address2': 'Ste F5',
#     'address3': None,
#     'city': 'Bellevue',
#     'zip_code': '98007',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['15552 Lake Hills Blvd',
#      'Ste F5',
#      'Bellevue, WA 98007']},
#    'phone': '+14254498748',
#    'display_phone': '(425) 449-8748',
#    'distance': 15431.183096727571}],
#  'total': 322,
#  'region': {'center': {'longitude': -122.33551025390625,
#    'latitude': 47.62541904760501}}}

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.josn().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
import pandas as pd
keys = get_keys('/Users/lawrencechew/.secret/yelp_api.json')
client_id = keys['client_id']
api_key = keys['api_key']
SEARCH_LIMIT = 50
term = 'Boba'
location = 'Seattle, WA'
url = 'https://api.yelp.com/v3/businesses/search'
headers = {
    'Authorization': f'Bearer {api_key}',
}

url_params = {
    'term': term.replace(' ', '+'),
    'location': location.replace(' ', '+'),
    'limit': SEARCH_LIMIT
}
def store_yelp(url, headers, url_params, offset_num):
    df = pd.DataFrame()
    for offset in range(0, offset_num, 50):
        url_params['offset'] = offset
        resp = requests.get(url, headers=headers, params=url_params)
        df = df.append(pd.DataFrame(resp.json()['businesses']))
    return df, resp.status_code
    

df, status_code = store_yelp(url, headers, url_params, 350)
status_code
# Out:
# 200

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an intial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
#Your code here
print(len(df))
df.head()
# Out:
# 322
#                       alias  \
# 0         20-oz-tea-seattle
# 1         young-tea-seattle
# 2            atulea-seattle
# 3  seattle-best-tea-seattle
# 4         boba-up-seattle-3
#
#                                           categories  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]
# 1  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...
# 2           [{'alias': 'tea', 'title': 'Tea Rooms'}]
# 3  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 4  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...
#
#                                        coordinates   display_phone  \
# 0  {'latitude': 47.63568, 'longitude': -122.32591}  (206) 712-6027
# 1  {'latitude': 47.59733, 'longitude': -122.32597}  (206) 682-6688
# 2  {'latitude': 47.61691, 'longitude': -122.31718}  (206) 413-5903
# 3  {'latitude': 47.59846, 'longitude': -122.32731}  (206) 749-9855
# 4  {'latitude': 47.65807, 'longitude': -122.31354}  (206) 547-8800
#
#       distance                      id  \
# 0  1343.324718  xI0ayTQVBIAkZpJiWk-SNQ
# 1  3202.101700  BFTaYXgJDxQY38MQZAWZFQ
# 2  1666.673565  BXjaJd5j3BJl8K4EVdSvEA
# 3  3052.028625  nDvwrhWdB7kjIwn2Z83lSQ
# 4  3991.404823  DD2UG9WnSJMvg2QHsQJeZQ
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/QfzSrq...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/gM3X_k...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/fyG1DE...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/Sw2oBm...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/9QeEr5...      False
#
#                                             location              name  \
# 0  {'address1': '1823 Eastlake Ave E', 'address2'...         20 OZ TEA
# 1  {'address1': '609 S Weller St', 'address2': 'U...         Young Tea
# 2  {'address1': '1715 12th Ave', 'address2': 'Sui...            Atulea
# 3  {'address1': '506 S King St', 'address2': '', ...  Seattle Best Tea
# 4  {'address1': '4141 University Way NE', 'addres...           Boba Up
#
#           phone price  rating  review_count        transactions  \
# 0  +12067126027     $     4.5           199                  []
# 1  +12066826688     $     4.5           398  [delivery, pickup]
# 2  +12064135903   NaN     4.5            69                  []
# 3  +12067499855     $     4.5           279                  []
# 4  +12065478800     $     4.0           113                  []
#
#                                                  url
# 0  https://www.yelp.com/biz/20-oz-tea-seattle?adj...
# 1  https://www.yelp.com/biz/young-tea-seattle?adj...
# 2  https://www.yelp.com/biz/atulea-seattle?adjust...
# 3  https://www.yelp.com/biz/seattle-best-tea-seat...
# 4  https://www.yelp.com/biz/boba-up-seattle-3?adj...

# %%
df['review_count'].hist()

# %%
df['rating'].hist()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.scatter(df['rating'],df['review_count'])

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
#Your code here
import folium
lat = 47.60
long = -122.33

base_map = folium.Map([lat, long], zoom_start=13)

for i in range(len(df)):
    loc_lat = df.iloc[i]['coordinates']['latitude']
    loc_long = df.iloc[i]['coordinates']['longitude']
    popup_text = df.iloc[i]['name'] + '\n' + str(df.iloc[i]['price']) + '\n' + str(df.iloc[i]['rating'])
    popup = folium.Popup(popup_text)
    
    marker = folium.Marker([loc_lat, loc_long], popup=popup)
    marker.add_to(base_map)

# %%
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
